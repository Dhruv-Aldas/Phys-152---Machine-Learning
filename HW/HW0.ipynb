# %% [markdown]
# # Homework 0

# %% [markdown]
# While we'll be using Google Colab or Jupyter servers to execute our code, keeping track of changes and such is a separate thing.  We'll use `git` for storing all the code for the course, both mine and yours.

# %% [markdown]
# First thing to do is to navigate to https://git.ucsc.edu, and get an account there.

# %% [markdown]
# Next, you'll need to create a new project to hold your work in phys 152.  You'll make this repo viewable by (at least) me, so don't re-use some other space!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Make a new project by clicking on the "New project" button in the upper-right, which brings you here:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Let's just create a blank project.  Give it a name, and description:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (I already have a phys152 area...  you can remove "test" from your project name.)  I suggest you create the project with a README.md file and maintain that.

# %% [markdown]
# Click create project, and your project should be available!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now click on the "Members" link on the panel, and add me to your project, and give me at least "Reporter" permissions:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, download a copy of HW1 from my git project: https://git.ucsc.edu/mhance/phys152/-/blob/master/HW/HW1.ipynb
# (if you do this by cloning my git repo to your local machine first, consider yourself a git expert!)
#
# Add your copy of HW1 to your own git project, and commit it, without making any changes.

# %% [markdown]
# When you have your copy of HW1 in git, submit (via Canvas) the URL to your un-touched version of HW1, similar to the URL I provided above.

# %% [markdown]
# That's it for HW 0!
